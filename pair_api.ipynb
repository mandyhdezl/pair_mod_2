# %% [markdown]
# Extraer datos de generación de energía renovable y no renovable a nivel nacional desde el 1 de enero de 2011 hasta el 31 de diciembre de 2022. La información debe ser recopilada a nivel mensual.
#
# Transformar los datos para incluir una columna nueva que identifique si la energía es renovable o no renovable.
#
# Almacenar los datos en un DataFrame con la siguiente estructura:
# tipo_energia
# tipo_generacion
# fecha
# valor

# %%
import pandas as pd
import requests

# %%
requests.get(f"https://apidatos.ree.es/es/datos/generacion/estructura-generacion?")
# Out:
# <Response [500]>

# %%
requests.get (f"https://apidatos.ree.es/es/datos/generacion/estructura-generacion?start_date=2011-01-01T00:00&end_date=2022-12-31T23:59&time_trunc=year&geo_trunc=electric_system&geo_limit=peninsular")
# Out:
# <Response [500]>

# %%
requests.get (f"https://apidatos.ree.es/es/datos/generacion/estructura-generacion?start_date=2011-01-01T00:00&end_date=2022-12-31T23:59&time_trunc=year")
# Out:
# <Response [500]>

# %%
requests.get (f"https://apidatos.ree.es/es/datos/balance/balance-electrico?start_date=2011-01-01T00:00&end_date=2011-12-31T23:59&time_trunc=day")
# Out:
# <Response [200]>

# %%
url_redata = requests.get (f"https://apidatos.ree.es/es/datos/balance/balance-electrico?start_date=2011-01-01T00:00&end_date=2011-12-31T23:59&time_trunc=month")

# %%
url_redata.json()
# Out:
# {'data': {'type': 'Balance de energía eléctrica',
#   'id': 'bal1',
#   'attributes': {'title': 'Balance de energía eléctrica',
#    'last-update': '2019-06-12T15:32:24.000+02:00',
#    'description': 'Balance eléctrico: asignación de unidades de producción según combustible principal.'},
#   'meta': {'cache-control': {'cache': 'MISS'}}},
#  'included': [{'type': 'Renovable',
#    'id': 'Renovable',
#    'attributes': {'title': 'Renovable',
#     'last-update': '2019-06-12T15:32:24.000+02:00',
#     'description': None,
#     'magnitude': None,
#     'content': [{'type': 'Hidráulica',
#       'id': '10288',
#       'groupId': 'Renovable',
#       'attributes': {'title': 'Hidráulica',
#        'description': '10288',
#        'color': '#0090d1',
#        'type': 'distinct',
#        'magnitude': None,
#        'composite': False,
#        'last-update': '2019-06-12T15:32:24.000+02:00',
#        'values': [{'value': 5119512.38,
#          'percentage': 0.5161699707381263,
# ...

# %%
type(url_redata)
# Out:
# requests.models.Response

# %%
type(url_redata.json())
# Out:
# dict

# %%
url_redata.json().keys()
# Out:
# dict_keys(['data', 'included'])

# %%
url_redata.json()["included"][0]["type"]
# Out:
# 'Renovable'

# %%
url_redata.json()["included"][0]
# Out:
# {'type': 'Renovable',
#  'id': 'Renovable',
#  'attributes': {'title': 'Renovable',
#   'last-update': '2019-06-12T15:32:24.000+02:00',
#   'description': None,
#   'magnitude': None,
#   'content': [{'type': 'Hidráulica',
#     'id': '10288',
#     'groupId': 'Renovable',
#     'attributes': {'title': 'Hidráulica',
#      'description': '10288',
#      'color': '#0090d1',
#      'type': 'distinct',
#      'magnitude': None,
#      'composite': False,
#      'last-update': '2019-06-12T15:32:24.000+02:00',
#      'values': [{'value': 5119512.38,
#        'percentage': 0.5161699707381263,
#        'datetime': '2011-01-01T00:00:00.000+01:00'},
#       {'value': 2998051.279,
#        'percentage': 0.37515501899960774,
#        'datetime': '2011-02-01T00:00:00.000+01:00'},
#       {'value': 3910363.276,
#        'percentage': 0.40707221720092784,
#        'datetime': '2011-03-01T00:00:00.000+01:00'},
#       {'value': 3537937.995,
#        'percentage': 0.4355212973981102,
# ...

# %%
len(url_redata.json()["included"])
# Out:
# 4

# %%
for d in url_redata.json():
    if d in url_redata["included"]:
        url_redata["included"]["datatime"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 2
#       1 for d in url_redata.json():
# ----> 2     if d in url_redata["included"]:
#       3         url_redata["included"]["datatime"]
#
# TypeError: 'Response' object is not subscriptable
